# %% [markdown]
# <a href="https://colab.research.google.com/github/saabir2003/pwskills/blob/main/Statistics_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment Questions

# %% [markdown]
# ###1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.

# %% [markdown]
# qualitative means categorial data ,the data which is non numerical data which can be categoried . in this data there are two types they are nominal and ordinal
#
# Nominal data:- it refers to data which has no order or unranked data
#
# Ex:- colors, names ,etc
#
# Ordinal data :- It refers to data which can be ranked in a particular way or an order
#
# Ex:- rank, salary :- high ,medium , low , ,etc
#
# they are: nominal , ordinal, interval and ratio:-
#
# Nominal data:- it refers to data which has no order or unranked data
#
# Ordinal data :- It refers to data which can be ranked in a particular way or an order
#
# interval data :- there is no zero starting point and values can have any range
#
# it refers of numerical data which can be grouped in a particular amounts of interval
#
# ratio data :- there is a zero starting point and we can compare any type of data in this form

# %% [markdown]
# ### 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median and mode with examples and situations where each is appropriate.

# %% [markdown]
# the measures of central tendency are mean , median , mode
#
# we have to use mean when there are no outliers
#
# we have to use median when there is a possibility of an outlier it finds out physical mean in a data
#
# we have to use mode when there is categorial data or non - numerial data
#
# Mean:- mean refers to average of all numerical data which possibily has no outliers
#
# Median :- median refers to middle most element in data which is sorted is an order
#
# mode:- Mode refers to highest frequerncy data in any group
#
# Examples for each are:-
#
# Mode:-
#
# The most common number in a set. For example, in the set of numbers {1, 1, 3, 4, 6, 7}, the mode is 1. If all the numbers are represented equally, there is no mode.
#
# Median:-
#
# The middle number in a set of numbers. For example, in the set of numbers {1, 1, 3, 4, 6, 7}, the middle numbers are 3 and 4. To find the median, add the middle numbers together and divide by 2, which gives a median of 3.5.
#
# Mean:-
#
# The average of a set of numbers. For example, if the data is 1, 2, 4, and 5, the mean is found by adding the numbers together to get 12, and then dividing by the number of data points.
#
# Mean and Median are used in numerical data
#
# mean is used where there are no outliers
#
# median is used when there are outliers
#
# mode is used in non numerical data or categorial data

# %% [markdown]
# ###3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?

# %% [markdown]
# In statistics, dispersion is a measure of how spread out or squeezed a distribution is.
#
#
# Variance and standard deviation are two common measures of dispersion that show how close data values are to the mean of a data set:
#
# Variance
#
#
# The mean squared difference between each data point and the mean. Variance is often used because it takes into account the spread of all data points. However, squaring the numbers can amplify the effect of large differences and skew the data.
#
# Standard deviation
#
# The square root of the variance. It's also known as the root mean square deviation. A small standard deviation means the data values are close to the mean, while a large standard deviation means the data values are spread out.

# %% [markdown]
# ###4. What is a box plot, and what can it tell you about the distribution of data?

# %% [markdown]
# A **box plot** (or **box-and-whisker plot**) is a chart that shows the distribution of a data set. It displays key values like the **minimum**, **first quartile (Q1)**, **median**, **third quartile (Q3)**, and **maximum**.
#
# - The **box** represents the middle 50% of the data (from Q1 to Q3) with a line at the **median**.
# - The **whiskers** extend from the box to show the range of the data, excluding outliers.
# - **Outliers** are values outside the whiskers, often shown as dots.
#
# ### What it tells you:
# - **Central tendency**: The median shows the middle value.
# - **Spread**: The size of the box (IQR) and whiskers show how spread out the data is.
# - **Skewness**: If the median is closer to one side of the box, the data is skewed.
# - **Outliers**: Any points outside the whiskers are outliers.
#
# In short, box plots give a clear picture of the data’s spread, central value, and whether there are any unusual outliers. They're especially useful for comparing different groups or datasets.

# %% [markdown]
# ###5. Discuss the role of random sampling in making inferences about populations.

# %% [markdown]
# we need We need random sampling because while making decisions in large or huge amounts of data it is impossible to get all the data correctly so we take we randomly assume small amounts of data or samples of data and we calculate mean and variance from this mean and variance we inferences about the population or the total data
#
# There are four different types of random sampling they are simple random sampling satisfied sampling cluster sampling and systematic sampling
#
# In simple random sampling all the data is picked randomly from all of the population or the sample this can have various disadvantages like Penis pet when a particular part of the sample has more amount of data or represents much more in the data than the sample will be represented more in the final sample
#
# To solve this problem we use stratosphere sampling In this type of sampling we group all the data in various or particular N number of groups with length N and from every particular group we select exactly one or at least one random sample in that group of that in that group of data
#
# In cluster sampling we generally we generally form a clusters or a groups of population and we select only particular clusters from that population after selecting the clusters we perform data analysis or sampling those selected clusters completely are taken into the sample part
#
# In systematic sampling we take every second or every 3rd or every nth element from the data this can have many advantages like representation of most random data as well as smallest amount of data as well as largest amount of data this can be done only on sorted data

# %% [markdown]
# ###6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?

# %% [markdown]
# Skewness refers to the inclination of data to the right side of the left side in a particular normal distribution a normal distribution has equal number of right parts and left parts inskeeped normal distribution either most of the part is on the right side and some part is on the left side or the other way around there are three types of skewness
#
# They are rightly skewed leftly skewed And no skewness
#
# In rightly skewed data the mean is greater than the median and the median is greater than the mod this happens when most amount of data or some amount of data is inclined to the right side
#
# In left fleece queue data the mode is greater than median and the median is greater than the mean this happens when most amount of the data is bent towards the left part of the normal distribution or inclined towards the left side
#
# In no skewness mean is equal to median is equal to mod where the left part of the normal distribution is exactly equal to the right side of the normal distribution and there is no skewness
#
# Skewness affects interpretation of data because mean median mode can be different for different types of skewness unlike in normal distribution where mean median mod or equal skewed data may have mean greater than median or mean less than median depending upon the skewness this can causeway inaccuracy in prediction or data analysis

# %% [markdown]
# ### 7. What is the interquartile range (IQR), and how is it used to detect outliers?

# %% [markdown]
# Inter quartile range refers to or is determined by By Q1 and Q3 of a boxplot or 25th percentile and 75th percentile in any data interquartile range it is a formula which is determined by these two percentiles mentioned above it basically estimates a range in which all of the data should be found any data beyond the range of Inter quarter range is usually considered as outliners inter quarter range can usually be graphically represented in a box plot or we can calculate the range using the formula
#
# The lower fence or the minimum value  Is known as lower interquartal range below this range every value is an outliner similarly the maximum value or the upper fence is known as higher intercoiler range above this range every value is an outlier this lower fence and upper fence can be calculated using the formula ir 1.5*Q3-Q1 Similarly we can calculate the same for the upper fence we can detect outliers graphically using the box plot or we can determine statistically using the formulas

# %% [markdown]
# ###8. Discuss the conditions under which the binomial distribution is used.

# %% [markdown]
# Binomial distribution is used when we know the probability of an event occurring and the probability of event not occurring when we need to calculate the probability of event occurring which is done for end times where N can be any positive number and combining all the combinations in permutations this is very useful when we have to calculate the P which is the probability of having an event Q which is a probability of not having an event and the combinations of all same or particular events this is used for discrete probability

# %% [markdown]
# ###9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).

# %% [markdown]
# Properties of the normal distribution are when the normal distribution has skewness of zero then mean is equal to mod
#
# The normal distribution has mean equal to zero and standard deviation is equal to 1 any distribution can be converted into the normal distribution using Z test which transforms any distribution into normal distribution and we can calculate the probability of an event occurring at a particular point
#
# The Empirical Lol 6895 and 99.7 is that the all of the probabilities in a normal distribution 68% of the all probabilities lie within the one standard deviation range between left and right and the all the probabilities on 95% of the probabilities lie between the two standard deviations left and right and all the 99.7 probabilities lie between the three points between the range left and right this is very useful in calculating the probabilities in any range

# %% [markdown]
# ###10. Provide a real-life example of a Poisson process and calculate the probability for a specific event

# %% [markdown]
# A **Poisson process** models events happening randomly and independently over time. For example, if a coffee shop receives an average of **5 customers per hour**, we can calculate the probability of exactly **3 customers** arriving in one hour.
#
# Using the Poisson formula:
#
# ![image.png](data:image/png;base64,...)\
# So, the probability of exactly 3 customers arriving in one hour is approximately **0.1396** or **13.96%**.

# %% [markdown]
# ###11. Explain what a random variable is and differentiate between discrete and continuous random variables.

# %% [markdown]
# A random variable is generally an estimation or a function where the input is a number and output is a probability of obtaining that number and input can be anything which is of a particular data type and output is a probability of obtaining that object or a data in the sample or in a population
#
# There are two types of random variables which are known as discrete and continuous random variables in discrete random variable Discrete random variable is used when we can count the amount of data or the number of data points when we can count the number of steps in a data it is represented in a graph using points
#
# Continuous random variable is usually a function with infinite data points and which has uncountable number of data points we can only estimate the probability of a data point in continuous random variable usually a range is given a range of real numbers is given
#
# In discrete random variable a range of natural numbers are whole numbers including negative integers or given

# %% [markdown]
# ###12. Provide an example dataset, calculate both covariance and correlation, and interpret the results

# %% [markdown]
# ![image2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image1.jpg](data:image/jpeg;base64,...)
